# %%
# LangChain
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate

# Other modules
from pydantic import BaseModel, Field
import os
import tempfile
import streamlit as st
import pandas as pd
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Defining our LLM

# %%
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY") # Loading the OpenAI API Key

# %%
# Creating the LLM object
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=OPENAI_API_KEY
)

# %% [markdown]
# ## Setting the PDF data

# %% [markdown]
# ### Loading the PDF data & transforming into chunks

# %%
loader = PyPDFLoader("data/Descripcion materias.pdf")

data = loader.load() # Loading the data

# Creating our splitter object to chunk the data
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=200,
    length_function=len,
    separators=["\n\n", "\n", " "]
)

chunks = text_splitter.split_documents(data) # Creating the chunks

# %%
chunks[0].page_content # ex: One of the chunks created
# Out:
# 'UNIVERSIDAD TECNOLÓGICA DE PANAMÁ \n \n \n \n \nSECRETARÍA GENERAL \n \n \n \n \n \n \nFACULTAD DE INGENIERÍA DE SISTEMAS COMPUTACIONALES \n \n \n \n \n \nDESCRIPCIÓN DE CURSO DE LA CARRERA DE  \nLICENCIATURA EN INGENIERÍA DE SISTEMAS Y COMPUTACIÓN \n \n \n \n \nAPROBADO POR EL CONSEJO ACADÉMICO EN REUNIÓN Nº 5/2003 DEL 23 DE JUNIO DE 2003 CON \nMODIFICACIONES EN REUNIÓN EXTRAORDINARIA Nº 10 -2003 DEL 14 DE NOVIEMBRE DE 2003 Y \nCON MODIFICACIÓN EN EL CONSEJO ACADÉMICO EN LA REUNIÓN Nº8 – 2004 (ORDINARIA) DEL \n19 DE NOVIEMBRE DE 2004 Y MODIFICACIÓN EN CONSEJO ACADÉMICO EN REUNIÓN Nº 05 -2007 \nDEL 6 DE JULIO DE 2007. Y MODIFICACIÓN EN SESIÓN ORDINARIA N° 03 -2008 DEL 11 DE JULIO DE \n2008. MODIFICACIÓN EN REUNIÓN N° 03 -2010 (EXTRAORDINARIA) DEL 26 DE MAYO DE 2010 . \nMODIFICACIONES EN EL C.A. EN REUNION No.03 -2014 DEL 9 DE MAYO DE 2014. MODIFICACIÓN \nEN CONSEJO ACADÉMICO EN REUNIÓN ORDINARIA N°07 -2015 DE 7 DE AGOSTO DE 2015.  \nMODIFICACIÓN EN LA SESIÓN ORDINARIA Nº 10 -2015 DE 16 DE OCTUBRE DE 2015.  \nMODIFICACIÓN EN CACAD -R-01-2021-02-2021 DEL 5 DE ENERO DE 2021. MODIFICADO EN CACAD -\nR-N°3-2023 (ORDINARIA) DEL 14 DE ABRIL DE 2023. MODIFICADO EN CACAD -R-04-2023 DEL 8 DE \nSEPTIEMBRE DE 2023.  MODIFICADO EN CACAD -R-04-2023, DEL 8 DE SEPTIEMBRE DE 2023. \nMODIFICADO EN CACAD-R-OD-02-2024, DEL 1 DE MARZO DE 2024. \n \n \nVIGENTE A PARTIR DEL PRIMER SEMESTRE DE 2024.'

# %% [markdown]
# ## Create embeddings

# %%
def create_embeddings():
    embeddings = OpenAIEmbeddings(
        model="text-embedding-3-small",
        api_key=OPENAI_API_KEY,
    )
    return embeddings

embedding_function = create_embeddings()

# %% [markdown]
# ### Creating the vector database

# %%
import uuid

def create_vectorstore(chunks, embedding_function, vectorstore_path):
    # Create a list for unique ids for each document based on the content
    ids = [str(uuid.uuid5(uuid.NAMESPACE_DNS, doc.page_content)) for doc in chunks]

    # Ensure that only unique ids are stored
    unique_ids = set()
    unique_chunks = []

    for id, chunk in zip(ids, chunks):
        if id not in unique_ids:
            unique_ids.add(id)
            unique_chunks.append(chunk)
    
    # Create a new Chroma database
    vectorstore = Chroma.from_documents(
        documents=unique_chunks,
        ids=list(unique_ids),
        embedding=embedding_function,
        persist_directory=vectorstore_path
    )

    vectorstore.persist()

    return vectorstore

# %%
vectorstore = create_vectorstore(
    chunks=chunks,
    embedding_function=embedding_function,
    vectorstore_path="vectorstore_chroma"
)

# %% [markdown]
# ### Query for relevant data

# %%
# Load vectorstore
vectorstore = Chroma(persist_directory="vectorstore_chroma", embedding_function=embedding_function)

# %%
# Creating the retriever with the parameter search_type="similarity"
retriever = vectorstore.as_retriever(search_type="similarity") 

# Retrieving the relevant chunks
relevant_chunks = retriever.invoke("Cual es la descripcion de la materia de 'ingenieria de software I'")
relevant_chunks
# Out:
# [Document(metadata={'moddate': '2024-05-10T18:26:23-05:00', 'creator': 'Microsoft® Word 2016', 'source': 'data/Descripcion materias.pdf', 'creationdate': '2024-05-10T18:26:23-05:00', 'title': 'UNIVERSIDAD TECNOLOGICA DE PANAMA', 'total_pages': 19, 'producer': 'Microsoft® Word 2016', 'page': 12, 'author': 'Addys', 'page_label': '13'}, page_content='apreciar los aspectos de hardware. Finalmente, la interacción con robots dotados de sistemas de \nmovilidad y percepción avanzados permitirá apreciar el potencial, complejidad y l imitaciones \nactuales de la tecnología, así como los aspectos más relevantes del software requerido. Se \npersigue que el estudiante desarrolle un proyecto de robótica que incluya el diseño, la \nprogramación y/o construcción de un sistema robótico, con énfasis  en aplicaciones prácticas en \nbase a sistemas inteligentes y en tareas de representación del espacio, construcción de mapas \nsensoriales, auto localización, seguimiento de trayectorias e interacción con otros robots o \nagentes basado en la utilización de sensores y actuadores que interactúen con el mundo real. \n \nAsignatura: INGENIERÍA DE SOFTWARE II    \nCódigo: 0753      Total de créditos:   3 \nHoras semanales de clase: 2   Horas semanales de Laboratorio:   2 \nRequisito: Ingeniería de Software I \n \nDESCRIPCIÓN: En este curso los estudiantes profundizan los conceptos de diseño al aprender \na establecer el comportamiento dinámico d e los sistemas, es decir cómo reaccionar ante \ndiversos acontecimientos.  Para su desarrollo los estudiantes hacen uso de los lenguajes de \nmodelado aprendidos en el curso de ingeniería de software I. También, se estudia cómo \npreparar el modelo de diseño para su implementación (construcción de componentes). Este tema \nincluye tópicos como el uso de patrones, como alternativa de modelado de objetos, ofreciendo'),
#  Document(metadata={'producer': 'Microsoft® Word 2016', 'total_pages': 19, 'title': 'UNIVERSIDAD TECNOLOGICA DE PANAMA', 'moddate': '2024-05-10T18:26:23-05:00', 'page_label': '11', 'creationdate': '2024-05-10T18:26:23-05:00', 'source': 'data/Descripcion materias.pdf', 'author': 'Addys', 'page': 10, 'creator': 'Microsoft® Word 2016'}, page_content='Asignatura:   MECÁNICA  \nCódigo:   8582      Total de créditos:   4 \nHoras semanales de clase: 4   Horas semanales de Laboratorio: 0 \nRequisito: Física I (Mecánica) \n \nDESCRIPCIÓN: Estática:  Introducción. Fuerzas concurrentes y coplanares en espacio.  \nFuerzas no concurrentes y coplanares en el espacio. Equilibrio de cuerpos rígidos. Centroide y \nmomentos de inercia. Análisis de estructuras simples. Fuerzas en vigas y cables. Fricción.  \nTrabajo v irtual.  Dinámica: Introducción. Vectores. Movimientos de partículas. Aplicaciones.  \nFuerza, masa y aceleración sobre partículas.  II Ley de Newton y ecuaciones de movimiento de \nun sistema de partícula. Movimiento rectilíneo y curvilíneo. Movimiento planet ario.  \nAplicaciones. Trabajo y energía. Impulso y momentum.  Cinemática de cuerpos rígidos.  Energía \ny momentum e cuerpos rígidos.  Vibraciones mecánicas. \n \nAsignatura:   INGENIERÍA DE SOFTWARE I  \nCódigo: 8581      Total de créditos:   4 \nHoras semanales de clase: 4   Horas semanales de Laboratorio:   1 \n \nDESCRIPCIÓN: En este curso los estudiantes aprenden los fundamentos del proceso de \ndesarrollo iterativo.  Se concentran en el análisis de requerimientos, definición de condiciones o \ncapacidades necesarias par a los usuarios, ofreciendo soluciones a un problema o en la \nconsecución de un proyecto. Especificación del comportamiento externo de los sistemas, \narquitectura general de los sistemas, componentes físicos de sistemas. Modelado de'),
#  Document(metadata={'moddate': '2024-05-10T18:26:23-05:00', 'page_label': '13', 'source': 'data/Descripcion materias.pdf', 'creationdate': '2024-05-10T18:26:23-05:00', 'creator': 'Microsoft® Word 2016', 'producer': 'Microsoft® Word 2016', 'author': 'Addys', 'page': 12, 'total_pages': 19, 'title': 'UNIVERSIDAD TECNOLOGICA DE PANAMA'}, page_content='la presentación de un proyecto en el que se evidencia la aplicación de los aspectos \ndesarrollados en clase. \n \nAsignatura:  HERRAMIENTA DE PROGRAMACIÓN APLICADA III \nCódigo: 1199      Total de créditos: 4 \nHoras semanales de clase: 3    Horas semanales de Laboratorio:   2 \nRequisitos: Estructura Discretas para Computación, Base de Datos II \n \nDESCRIPCIÓN: \n \nAsignatura:   INGENIERÍA DE SISTEMAS ROBÓTICOS  \nCódigo: 0758      Total de créditos: 4 \nHoras semanales de clase: 3   Horas semanales de Laboratorio: 2 \nRequisito: Inteligencia Artificial \n \nDESCRIPCIÓN: La Ingeniería de Sistemas Robóticos tiene como propósito familiarizar al \nestudiante con los distintos componentes involucrados en la c reación y operación de un robot \nmóvil. La asignatura incluye distintas experiencias de laboratorio que involucran desde la \ninteracción con los elementos de bajo nivel, como microprocesadores que controlan actuadores \ny sensores, hasta elementos de alto nive l, como computadores encargados de la toma de \ndecisiones. Mediante la utilización de kits robóticos, los estudiantes podrán conocer los aspectos \nrelevantes a la creación de robots. Por su parte, la interacción directa con actuadores, sensores \ny microprocesadores, así como la implementación de sistemas de movilidad básicos, permitirá \napreciar los aspectos de hardware. Finalmente, la interacción con robots dotados de sistemas de \nmovilidad y percepción avanzados permitirá apreciar el potencial, complejidad y l imitaciones'),
#  Document(metadata={'page': 9, 'creator': 'Microsoft® Word 2016', 'producer': 'Microsoft® Word 2016', 'creationdate': '2024-05-10T18:26:23-05:00', 'title': 'UNIVERSIDAD TECNOLOGICA DE PANAMA', 'source': 'data/Descripcion materias.pdf', 'page_label': '10', 'moddate': '2024-05-10T18:26:23-05:00', 'total_pages': 19, 'author': 'Addys'}, page_content='III AÑO   \n \nAsignatura:  ANÁLISIS DE DATOS Y TOMA DE DECISIONES PARA COMP.   \nCódigo: 1195      Total de créditos: 4 \nHoras semanales de clase:3    Horas semanales de Laboratorio:  2 \nRequisito: Herramientas de Programación Aplicada II \n \nDESCRIPCIÓN: \n \n \n \nAsignatura:  HERRAMIENTAS DE COMPUTACIÓN GRÁFICA   \nCódigo: 1196      Total de créditos: 3 \nHoras semanales de clase:2    Horas semanales de Laboratorio: 3 \nRequisito: Dibujo Asistido por Computadora, Estructura de Datos II  \n \nDESCRIPCIÓN: \n \nAsignatura:   INTELIGENCIA ARTIFICIAL  \nCódigo: 1197      Total de créditos:  4 \nHoras semanales de clase: 3   Horas semanales de Laboratorio:   2 \nRequisito: Estructura de Datos II \n \nDESCRIPCIÓN: En esta asignatura se presenta la fundamentación teórica de la Inteligencia \nArtificial, trabajando en base ejemplos prácticos sobre la aplicabilidad de este innovador campo \nde la informática. La asignatura de Inteligencia Artificial es parte esencial en la formación del \nestudiante de la carrera de Ingeniería de Sistemas y Computación, puesto que aborda temas de \nsingular importancia en el diseño de soluciones informáticas de  vanguardia, siendo este el \nnuevo paradigma orientador para el diseño de software de actualidad. El estudiante aprenderá \na manejar las estructuras de representación de conocimiento, y los procedimientos relacionadas \ncon su administración, con el propósito de que logre implementar proyectos de casos reales,')]

# %% [markdown]
# ## Generate responses

# %%
# Prompt template
PROMPT_TEMPLATE = """
You are an assistant for question-answering tasks.
Use the following pieces of retrieved context to answer the question.
If the answer is not contained within the context, say "I don't know".

Context: {context}

Answer the question based on the above context: {question}
"""

# %%
# Saving the context
context_text = "\n\n---\n\n".join([chunk.page_content for chunk in chunks])

# Creating the prompt template
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
prompt = prompt_template.format(context=context_text, question="Que materias tengo en mi primer semestre de mi carrera?")

print(prompt)

# %% [markdown]
# ### Using langchain expression language

# %%
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt_template
    | llm
)

rag_chain.invoke("Cual es la descripcion de la materia de ingenieria de software I?")
# Out:
# AIMessage(content='En el curso de Ingeniería de Software I, los estudiantes aprenden los fundamentos del proceso de desarrollo iterativo. Se concentran en el análisis de requerimientos, definición de condiciones o capacidades necesarias para los usuarios, ofreciendo soluciones a un problema o en la consecución de un proyecto. También se trabaja en la especificación del comportamiento externo de los sistemas, arquitectura general de los sistemas, y los componentes físicos de los mismos.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 1466, 'total_tokens': 1551, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_6b23b3aa8a', 'id': 'chatcmpl-D5YBTuObphhQoO4UzEQKL9QSF8ZJ6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c290f-9dfb-71f1-9759-3356c3114e08-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1466, 'output_tokens': 85, 'total_tokens': 1551, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
