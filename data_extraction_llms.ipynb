# %%
# LangChain
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate

# Other modules
from pydantic import BaseModel, Field
import os
import tempfile
import streamlit as st
import pandas as pd
from dotenv import load_dotenv

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Defining our LLM

# %%
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY") # Loading the OpenAI API Key

# %%
# Creating the LLM object
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=OPENAI_API_KEY
)

# %% [markdown]
# ## Setting the PDF data

# %% [markdown]
# ### Loading the PDF data & transforming into chunks

# %%
loader = PyPDFLoader("data\Pensum.pdf")

data = loader.load() # Loading the data

# Creating our splitter object to chunk the data
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=200,
    length_function=len,
    separators=["\n\n", "\n", " "]
)

chunks = text_splitter.split_documents(data) # Creating the chunks

# %%
chunks[0].page_content # ex: One of the chunks created
# Out:
# 'UNIVERSIDAD TECNOLÓGICA DE PANAMÁFUTP-SG-JRHA-04-1SECRETARÍA GENERALPLAN DE ESTUDIOFACULTAD:INGENIERÍA DE SISTEMAS COMPUTACIONALESCARRERA:LICENCIATURA EN INGENIERIA DE SISTEMAS Y COMPUTACIONNUM.COD. REQUISITOSASIG.ASIG.ASIGNATURA(COD-ASIG.)CLAS.LAB.CRED.I AÑOPRIMER SEMESTRE17987             505CÁLCULO   I20855             22$$3DIBUJO ASISTIDO POR COMPUTADORAS30741**             324DESARROLLO LÓGICO Y ALGORÍTMOS48353**             32$$4TECNOLOGÍA DE INFORMACIÓN  Y COMUNICAC.50742             303REDACCIÓN DE INFORMES Y EXPRESIÓN ORAL60744             505INGLÉS CONVERSACIONALI AÑOSEGUNDO SEMESTRE77988 7987            505CÁLCULO II88322 7987            404CÁLCULO III90743** 0741            32$$4HERRAMIENTAS DE PROGRAMACIÓN APLICADA I108361**             31$$3SISTEMAS COLABORATIVOS110608             23$$3INTRODUCCIÓN A LA QUÍMICA121392             223ESTADÍSTICA APLICADA A TIC138461             313INGENIERIA AMBIENTALII AÑOVERANO141263             303GEOGRAFÍA DE PANAMÁ151274             303HISTORIA DE PANAMÁII AÑOPRIMER SEMESTRE160709 7988            505ECUACIONES DIFERENCIALES ORDINARIAS178362 0743            32$$4ESTRUCTURA DE DATOS I188319 7988            42$$5FÍSICA I (MECÁNICA)191394 1392            22$$3PROBABILIDAD APLICADA A TIC200745** 0743            32$$4HERRAMIENTAS DE PROGRAMACIÓN APLICADA II210592** 0741            414ESTRUCTURAS DISCRETAS PARA COMPUTACIÓNII AÑOSEGUNDO SEMESTRE228394** 8362            32$$4ESTRUCTURA DE DATOS II238320 8319            42$$5FÍSICA II'

# %% [markdown]
# ## Create embeddings

# %%
def create_embeddings():
    embeddings = OpenAIEmbeddings(
        model="text-embedding-3-small",
        api_key=OPENAI_API_KEY,
    )
    return embeddings

embedding_function = create_embeddings()

# %% [markdown]
# ### Creating the vector database

# %%
import uuid

def create_vectorstore(chunks, embedding_function, vectorstore_path):
    # Create a list for unique ids for each document based on the content
    ids = [str(uuid.uuid5(uuid.NAMESPACE_DNS, doc.page_content)) for doc in chunks]

    # Ensure that only unique ids are stored
    unique_ids = set()
    unique_chunks = []

    for id, chunk in zip(ids, chunks):
        if id not in unique_ids:
            unique_ids.add(id)
            unique_chunks.append(chunks)
    
    # Create a new Chroma database
    vectorstore = Chroma.from_documents(
        documents=unique_chunks,
        ids=list(unique_ids),
        embedding=embedding_function,
        persist_directory=vectorstore_path
    )

    vectorstore.persist()

    return vectorstore

# %%
vectorstore = create_vectorstore(
    chunks=chunks,
    embedding_function=embedding_function,
    vectorstore_path="vectorstore_chroma"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 vectorstore = create_vectorstore(
#       2     chunks=chunks,
#       3     embedding_function=embedding_function,
#       4     vectorstore_path="vectorstore_chroma"
#       5 )
#
# Cell In[39], line 17, in create_vectorstore(chunks, embedding_function, vectorstore_path)
#      14         unique_chunks.append(chunks)
#      16 # Create a new Chroma database
# ---> 17 vectorstore = Chroma.from_documents(
#      18     documents=unique_chunks,
#      19     ids=list(unique_ids),
#      20     embedding=embedding_function,
#      21     persist_directory=vectorstore_path
#      22 )
#      24 vectorstore.persist()
#      26 return vectorstore
#
# File c:\Users\rtova\OneDrive\Documentos\Projects\rag_pdf_chatbot\myenv\Lib\site-packages\langchain_community\vectorstores\chroma.py:885, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     852 @classmethod
#     853 def from_documents(
#     854     cls: Type[Chroma],
#    (...)    865     **kwargs: Any,
#     866 ) -> Chroma:
#     867     """Create a Chroma vectorstore from a list of documents.
#     868
#     869     If a persist_directory is specified, the collection will be persisted there.
#    (...)    883         Chroma: Chroma vectorstore.
#     884     """
# --> 885     texts = [doc.page_content for doc in documents]
#     886     metadatas = [doc.metadata for doc in documents]
#     887     return cls.from_texts(
#     888         texts=texts,
#     889         embedding=embedding,
#    (...)    897         **kwargs,
#     898     )
#
# File c:\Users\rtova\OneDrive\Documentos\Projects\rag_pdf_chatbot\myenv\Lib\site-packages\langchain_community\vectorstores\chroma.py:885, in <listcomp>(.0)
#     852 @classmethod
#     853 def from_documents(
#     854     cls: Type[Chroma],
#    (...)    865     **kwargs: Any,
#     866 ) -> Chroma:
#     867     """Create a Chroma vectorstore from a list of documents.
#     868
#     869     If a persist_directory is specified, the collection will be persisted there.
#    (...)    883         Chroma: Chroma vectorstore.
#     884     """
# --> 885     texts = [doc.page_content for doc in documents]
#     886     metadatas = [doc.metadata for doc in documents]
#     887     return cls.from_texts(
#     888         texts=texts,
#     889         embedding=embedding,
#    (...)    897         **kwargs,
#     898     )
#
# AttributeError: 'list' object has no attribute 'page_content'
